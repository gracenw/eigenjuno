# %%
# import libraries and navigate to directory
# %cd '/home/uzumochi/eigenjuno/DATA/RAW/PERIJOVE-17'
from stitch import *
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os, threading, time, multiprocessing, sys, json, math, zipfile, fnmatch, shutil, pickle, logging
# Out:
# /home/uzumochi/eigenjuno/DATA/RAW/PERIJOVE-17
# CSPICE_N0067

# %%
# handle occasional spice exceptions - code still runs fine
f_err = sys.stderr = open('errors.txt', 'w')
get_ipython().log.handlers[0].stream = f_err
get_ipython().log.setLevel(logging.INFO)

# %%
# unzip junocam website data - just drop zip files in perijove directory and run this block!
for file in sorted(os.listdir('.')):
    meta_num = file.split('-')[0]
    if fnmatch.fnmatch(file, '*-Data.zip') and not os.path.isfile(meta_num + '-Metadata.json'):
        print('Unzipped', meta_num, 'image and data')
        with zipfile.ZipFile(file, 'r') as zip_ref:
            names = zip_ref.namelist()
            for n in names:
                zip_ref.extract(n)
        with zipfile.ZipFile(meta_num + '-ImageSet.zip', 'r') as zip_ref:
            names = zip_ref.namelist()
            for n in names:
                if 'raw' in n:
                    zip_ref.extract(n)
for file in sorted(os.listdir('.')):
    if fnmatch.fnmatch(file, '*.zip'):
        os.remove(file)

if os.path.isdir('DataSet'):
    for file in sorted(os.listdir('DataSet')):
        shutil.move('DataSet/' + file, file)
    os.rmdir('DataSet')

if os.path.isdir('ImageSet'):
    for file in sorted(os.listdir('ImageSet')):
        shutil.move('ImageSet/' + file, file)
    os.rmdir('ImageSet')

# %%
# stitch function for thread, taken largely from the reddit post linked in repo desc
def stitch(meta_num):
    im_info = meta_num + '-Metadata.json'
    with open(im_info, 'r') as json_file:
        im_info_dir = json.load(json_file)
        image = im_info_dir['FILE_NAME']
        image_time = im_info_dir['IMAGE_TIME']
    
    img = Image.open(image)
    im_ar = np.array(img)
    
    s1, s2 = im_ar.shape

    start_time = im_info_dir["START_TIME"]
    frame_delay = float(im_info_dir["INTERFRAME_DELAY"].split()[0])+0.001
    
    start_correction, frame_delay = correct_image_start_time_and_frame_delay(im_ar, start_time, frame_delay)
    
    framelets = generate_framelets(im_ar, start_time, start_correction, frame_delay) # im_ar.astype(np.int) ** 2

    cam_pos, cam_orient = get_junocam_jupiter_rel_pos_orient(start_time, start_correction + 17 * frame_delay)

    y, x = np.mgrid[-1024:1024,-1024:1024]
    x += 260
    y += 95
    rays = np.concatenate([x[...,None], y[...,None], np.ones(((2048),(2048),1))*fl[0]], axis=-1)
    rays = rays.dot(cam_orient)

    surface_raster, surface_mask = project_onto_jupiter_surf(cam_pos, rays)
    
    np.save(meta_num + '-Raster', surface_raster)
    
    colors = np.zeros(((2048),(2048),3))
    color_counts = np.zeros(((2048),(2048),3))

    for k,framelet in enumerate(framelets):
        print(str(meta_num) + ': processing framelet {} of {}..'.format(k+1, len(framelets)))
        col = framelet.color
        brightnesses, valid_map = framelet.get_pixel_val_at_surf_point(surface_raster)
        colors[...,2-col] += brightnesses
        color_counts[...,2-col] += valid_map

    colors /= np.maximum(color_counts, 1)
    colors *= 255 / np.max(colors)

    colors = colors.astype(np.uint8)

    new_img = Image.fromarray(colors)
    new_img.save(str(meta_num) + '-Stitched.png')

# %%
#begin multithreaded execution - this will process all images in a directory, assuming they are from the same perijove
img_nums = []
for file in os.listdir('.'):
    if file.endswith('.json') and not os.path.isfile(file.split('-')[0] + '-Stitched.png'):
        img_nums.append(file.split('-')[0])
print_str = 'Processing the following images: '
for im in img_nums:
    print_str += (im + ', ')
print_str = print_str[:-2]
print(print_str)

num_cpus = multiprocessing.cpu_count() - 1
curr = 0

while curr < len(img_nums):
    threads = []
    num_threads = num_cpus if num_cpus < len(img_nums) else len(img_nums)
    print('Running ' + str(num_threads) + ' threads')
    for t in range(num_threads):
        try:
            threads.append(threading.Thread(target = stitch, args = (str(img_nums[curr]), )))
        except IndexError:
            print('\nStarting new round of threads')
        threads[t].start()
        curr += 1
    for t in threads:
        t.join()

print("End stitching threads")
# Out:
# Processing the following images: 6364, 6365, 6366
# Running 3 threads
# 6365: processing framelet 1 of 84..
# 6366: processing framelet 1 of 78..
# 6364: processing framelet 1 of 90..
# /home/uzumochi/eigenjuno/STITCHING/stitch.py:222: RuntimeWarning: invalid value encountered in true_divide
#   cos_angle = -scalar_prod/(np.linalg.norm(rays, axis=-1)*np.linalg.norm(surf_normal, axis=-1))
# /home/uzumochi/eigenjuno/STITCHING/stitch.py:235: RuntimeWarning: invalid value encountered in true_divide
#   cos_angle = -scalar_prod / (np.linalg.norm(sun_rays, axis=-1) * np.linalg.norm(surf_normal, axis=-1))
# 6365: processing framelet 2 of 84..
# 6364: processing framelet 2 of 90..
# 6366: processing framelet 2 of 78..
# 6365: processing framelet 3 of 84..
# 6364: processing framelet 3 of 90..
# 6366: processing framelet 3 of 78..
# 6365: processing framelet 4 of 84..
# 6364: processing framelet 4 of 90..
# 6366: processing framelet 4 of 78..
# 6365: processing framelet 5 of 84..
# 6364: processing framelet 5 of 90..
# 6366: processing framelet 5 of 78..
# 6365: processing framelet 6 of 84..
# 6364: processing framelet 6 of 90..
# 6366: processing framelet 6 of 78..
# 6364: processing framelet 7 of 90..
# 6365: processing framelet 7 of 84..
# 6366: processing framelet 7 of 78..
# 6364: processing framelet 8 of 90..
# 6365: processing framelet 8 of 84..
# 6366: processing framelet 8 of 78..
# 6364: processing framelet 9 of 90..
# 6365: processing framelet 9 of 84..
# 6366: processing framelet 9 of 78..
# 6364: processing framelet 10 of 90..
# 6365: processing framelet 10 of 84..
# 6366: processing framelet 10 of 78..
# 6364: processing framelet 11 of 90..
# 6365: processing framelet 11 of 84..
# 6366: processing framelet 11 of 78..
# 6364: processing framelet 12 of 90..
# 6365: processing framelet 12 of 84..
# 6366: processing framelet 12 of 78..
# 6364: processing framelet 13 of 90..
# 6365: processing framelet 13 of 84..
# 6366: processing framelet 13 of 78..
# 6364: processing framelet 14 of 90..
# 6365: processing framelet 14 of 84..
# 6366: processing framelet 14 of 78..
# 6364: processing framelet 15 of 90..
# 6365: processing framelet 15 of 84..
# 6366: processing framelet 15 of 78..
# 6364: processing framelet 16 of 90..
# 6365: processing framelet 16 of 84..
# 6366: processing framelet 16 of 78..
# 6364: processing framelet 17 of 90..
# 6365: processing framelet 17 of 84..
# 6366: processing framelet 17 of 78..
# 6364: processing framelet 18 of 90..
# 6365: processing framelet 18 of 84..
# 6366: processing framelet 18 of 78..
# 6364: processing framelet 19 of 90..
# 6365: processing framelet 19 of 84..
# 6366: processing framelet 19 of 78..
# 6364: processing framelet 20 of 90..
# 6365: processing framelet 20 of 84..
# 6366: processing framelet 20 of 78..
# 6364: processing framelet 21 of 90..
# 6365: processing framelet 21 of 84..
# 6366: processing framelet 21 of 78..
# 6364: processing framelet 22 of 90..
# 6365: processing framelet 22 of 84..
# 6366: processing framelet 22 of 78..
# 6364: processing framelet 23 of 90..
# 6365: processing framelet 23 of 84..
# 6366: processing framelet 23 of 78..
# 6364: processing framelet 24 of 90..
# 6365: processing framelet 24 of 84..
# 6366: processing framelet 24 of 78..
# 6364: processing framelet 25 of 90..
# 6365: processing framelet 25 of 84..
# 6366: processing framelet 25 of 78..
# 6364: processing framelet 26 of 90..
# 6365: processing framelet 26 of 84..
# 6366: processing framelet 26 of 78..
# 6364: processing framelet 27 of 90..
# 6365: processing framelet 27 of 84..
# 6366: processing framelet 27 of 78..
# 6364: processing framelet 28 of 90..
# 6365: processing framelet 28 of 84..
# 6366: processing framelet 28 of 78..
# 6364: processing framelet 29 of 90..
# 6365: processing framelet 29 of 84..
# 6366: processing framelet 29 of 78..
# 6364: processing framelet 30 of 90..
# 6365: processing framelet 30 of 84..
# 6366: processing framelet 30 of 78..
# 6364: processing framelet 31 of 90..
# 6365: processing framelet 31 of 84..
# 6366: processing framelet 31 of 78..
# 6364: processing framelet 32 of 90..
# 6365: processing framelet 32 of 84..
# 6366: processing framelet 32 of 78..
# 6364: processing framelet 33 of 90..
# 6365: processing framelet 33 of 84..
# 6366: processing framelet 33 of 78..
# 6364: processing framelet 34 of 90..
# 6365: processing framelet 34 of 84..
# 6366: processing framelet 34 of 78..
# 6364: processing framelet 35 of 90..
# 6365: processing framelet 35 of 84..
# 6366: processing framelet 35 of 78..
# 6364: processing framelet 36 of 90..
# 6365: processing framelet 36 of 84..
# 6366: processing framelet 36 of 78..
# 6364: processing framelet 37 of 90..
# 6365: processing framelet 37 of 84..
# 6366: processing framelet 37 of 78..
# 6364: processing framelet 38 of 90..
# 6365: processing framelet 38 of 84..
# 6366: processing framelet 38 of 78..
# 6364: processing framelet 39 of 90..
# 6365: processing framelet 39 of 84..
# 6366: processing framelet 39 of 78..
# 6364: processing framelet 40 of 90..
# 6365: processing framelet 40 of 84..
# 6366: processing framelet 40 of 78..
# 6364: processing framelet 41 of 90..
# 6365: processing framelet 41 of 84..
# 6366: processing framelet 41 of 78..
# 6364: processing framelet 42 of 90..
# 6365: processing framelet 42 of 84..
# 6366: processing framelet 42 of 78..
# 6364: processing framelet 43 of 90..
# 6365: processing framelet 43 of 84..
# 6366: processing framelet 43 of 78..
# 6364: processing framelet 44 of 90..
# 6365: processing framelet 44 of 84..
# 6366: processing framelet 44 of 78..
# 6364: processing framelet 45 of 90..
# 6365: processing framelet 45 of 84..
# 6366: processing framelet 45 of 78..
# 6364: processing framelet 46 of 90..
# 6365: processing framelet 46 of 84..
# 6366: processing framelet 46 of 78..
# 6364: processing framelet 47 of 90..
# 6365: processing framelet 47 of 84..
# 6366: processing framelet 47 of 78..
# 6364: processing framelet 48 of 90..
# 6365: processing framelet 48 of 84..
# 6366: processing framelet 48 of 78..
# 6364: processing framelet 49 of 90..
# 6365: processing framelet 49 of 84..
# 6366: processing framelet 49 of 78..
# 6364: processing framelet 50 of 90..
# 6365: processing framelet 50 of 84..
# 6366: processing framelet 50 of 78..
# 6364: processing framelet 51 of 90..
# 6365: processing framelet 51 of 84..
# 6366: processing framelet 51 of 78..
# 6364: processing framelet 52 of 90..
# 6365: processing framelet 52 of 84..
# 6366: processing framelet 52 of 78..
# 6364: processing framelet 53 of 90..
# 6365: processing framelet 53 of 84..
# 6366: processing framelet 53 of 78..
# 6364: processing framelet 54 of 90..
# 6365: processing framelet 54 of 84..
# 6366: processing framelet 54 of 78..
# 6364: processing framelet 55 of 90..
# 6365: processing framelet 55 of 84..
# 6366: processing framelet 55 of 78..
# 6364: processing framelet 56 of 90..
# 6365: processing framelet 56 of 84..
# 6366: processing framelet 56 of 78..
# 6364: processing framelet 57 of 90..
# 6365: processing framelet 57 of 84..
# 6366: processing framelet 57 of 78..
# 6364: processing framelet 58 of 90..
# 6365: processing framelet 58 of 84..
# 6366: processing framelet 58 of 78..
# 6364: processing framelet 59 of 90..
# 6365: processing framelet 59 of 84..
# 6366: processing framelet 59 of 78..
# 6364: processing framelet 60 of 90..
# 6365: processing framelet 60 of 84..
# 6366: processing framelet 60 of 78..
# 6364: processing framelet 61 of 90..
# 6365: processing framelet 61 of 84..
# 6366: processing framelet 61 of 78..
# 6364: processing framelet 62 of 90..
# 6365: processing framelet 62 of 84..
# 6366: processing framelet 62 of 78..
# 6364: processing framelet 63 of 90..
# 6365: processing framelet 63 of 84..
# 6366: processing framelet 63 of 78..
# 6364: processing framelet 64 of 90..
# 6365: processing framelet 64 of 84..
# 6366: processing framelet 64 of 78..
# 6364: processing framelet 65 of 90..
# 6365: processing framelet 65 of 84..
# 6366: processing framelet 65 of 78..
# 6364: processing framelet 66 of 90..
# 6365: processing framelet 66 of 84..
# 6366: processing framelet 66 of 78..
# 6364: processing framelet 67 of 90..
# 6365: processing framelet 67 of 84..
# 6366: processing framelet 67 of 78..
# 6364: processing framelet 68 of 90..
# 6365: processing framelet 68 of 84..
# 6366: processing framelet 68 of 78..
# 6364: processing framelet 69 of 90..
# 6365: processing framelet 69 of 84..
# 6366: processing framelet 69 of 78..
# 6364: processing framelet 70 of 90..
# 6365: processing framelet 70 of 84..
# 6366: processing framelet 70 of 78..
# 6364: processing framelet 71 of 90..
# 6365: processing framelet 71 of 84..
# 6365: processing framelet 72 of 84..
# 6366: processing framelet 71 of 78..
# 6365: processing framelet 73 of 84..
# 6364: processing framelet 72 of 90..
# 6366: processing framelet 72 of 78..
# 6365: processing framelet 74 of 84..
# 6364: processing framelet 73 of 90..
# 6366: processing framelet 73 of 78..
# 6365: processing framelet 75 of 84..
# 6364: processing framelet 74 of 90..
# 6366: processing framelet 74 of 78..
# 6365: processing framelet 76 of 84..
# 6364: processing framelet 75 of 90..
# 6366: processing framelet 75 of 78..
# 6365: processing framelet 77 of 84..
# 6364: processing framelet 76 of 90..
# 6366: processing framelet 76 of 78..
# 6365: processing framelet 78 of 84..
# 6364: processing framelet 77 of 90..
# 6366: processing framelet 77 of 78..
# 6365: processing framelet 79 of 84..
# 6364: processing framelet 78 of 90..
# 6366: processing framelet 78 of 78..
# 6365: processing framelet 80 of 84..
# 6364: processing framelet 79 of 90..
# 6365: processing framelet 81 of 84..
# 6364: processing framelet 80 of 90..
# 6365: processing framelet 82 of 84..
# 6364: processing framelet 81 of 90..
# 6365: processing framelet 83 of 84..
# 6364: processing framelet 82 of 90..
# 6365: processing framelet 84 of 84..
# 6364: processing framelet 83 of 90..
# 6364: processing framelet 84 of 90..
# 6364: processing framelet 85 of 90..
# 6364: processing framelet 86 of 90..
# 6364: processing framelet 87 of 90..
# 6364: processing framelet 88 of 90..
# 6364: processing framelet 89 of 90..
# 6364: processing framelet 90 of 90..
# End stitching threads
